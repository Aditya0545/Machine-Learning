# %%
import pandas as pd
from pydataset import data
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.naive_bayes import GaussianNB

# %%
# !ls
# Out:
# Untitled.ipynb

# %%
df = data("DoctorAUS")
df
# Out:
#       sex   age  income insurance  illness  actdays  hscore chcond  doctorco  \
# 1       1  0.19    0.55  levyplus        1        4       1     np         1
# 2       1  0.19    0.45  levyplus        1        2       1     np         1
# 3       0  0.19    0.90   medlevy        3        0       0     np         1
# 4       0  0.19    0.15   medlevy        1        0       0     np         1
# 5       0  0.19    0.45   medlevy        2        5       1     la         1
# ...   ...   ...     ...       ...      ...      ...     ...    ...       ...
# 5186    1  0.22    0.55   medlevy        0        0       0     np         0
# 5187    0  0.27    1.30   medlevy        0        0       1     np         0
# 5188    1  0.37    0.25  freerepa        1        0       1     np         0
# 5189    1  0.52    0.65   medlevy        0        0       0     np         0
# 5190    0  0.72    0.25  freerepa        0        0       0     np         0
#
#       nondocco  hospadmi  hospdays  medecine  prescrib  nonpresc
# 1            0         0         0         1         1         0
# 2            0         0         0         2         1         1
# 3            0         1         4         2         1         1
# 4            0         0         0         0         0         0
# 5            0         0         0         3         1         2
# ...        ...       ...       ...       ...       ...       ...
# 5186         0         0         0         0         0         0
# 5187         0         0         0         3         0         3
# 5188         0         0         0         0         0         0
# 5189         0         0         0         0         0         0
# 5190         0         0         0         0         0         0
#
# [5190 rows x 15 columns]

# %%
df.sample(5)
# Out:
#       sex   age  income insurance  illness  actdays  hscore chcond  doctorco  \
# 4150    1  0.67    0.35   medlevy        0        0       0     la         0
# 2024    1  0.52    0.35  freerepa        3        0       1     la         0
# 594     1  0.57    0.45  freerepa        1        0       6    nla         1
# 825     0  0.72    0.75  levyplus        1        0       0     np         1
# 1048    0  0.72    0.25  freerepa        0        0       2     la         1
#
#       nondocco  hospadmi  hospdays  medecine  prescrib  nonpresc
# 4150         0         0         0         2         1         1
# 2024         0         0         0         1         1         0
# 594          0         1         7         1         1         0
# 825          0         0         0         0         0         0
# 1048         0         0         0         0         0         0

# %%
df.dtypes
# Out:
# sex            int64
# age          float64
# income       float64
# insurance     object
# illness        int64
# actdays        int64
# hscore         int64
# chcond        object
# doctorco       int64
# nondocco       int64
# hospadmi       int64
# hospdays       int64
# medecine       int64
# prescrib       int64
# nonpresc       int64
# dtype: object

# %%
df.nunique()
# Out:
# sex           2
# age          12
# income       14
# insurance     4
# illness       6
# actdays      15
# hscore       13
# chcond        3
# doctorco     10
# nondocco     12
# hospadmi      6
# hospdays     13
# medecine      9
# prescrib      9
# nonpresc      9
# dtype: int64

# %%
X = df[["age", "income", "sex", "illness", "actdays", "hscore", "doctorco", "nondocco", "hospadmi", "hospdays", "medecine", "prescrib"]]
Y = df["insurance"]
df.sample(5)
# Out:
#       sex   age  income insurance  illness  actdays  hscore chcond  doctorco  \
# 2551    0  0.72    0.25  freerepa        2        0       1     np         0
# 642     1  0.62    0.25  freerepa        5        3       1    nla         1
# 19      1  0.19    0.45  levyplus        1        0       0     np         2
# 3396    0  0.57    0.65  levyplus        1        0       0     np         0
# 4196    1  0.72    0.25  levyplus        0        0       0    nla         0
#
#       nondocco  hospadmi  hospdays  medecine  prescrib  nonpresc
# 2551         0         0         0         0         0         0
# 642          0         0         0         7         6         1
# 19           0         0         0         1         1         0
# 3396         0         0         0         0         0         0
# 4196         1         0         0         0         0         0

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=42)

# %%
clf = GaussianNB()
clf.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred = clf.predict(x_test)
print(f"Classiffication Report : {classification_report(y_test, y_pred)}")
# Out:
# Classiffication Report :               precision    recall  f1-score   support
#
#      freepor       0.29      0.13      0.18        67
#     freerepa       0.58      0.54      0.56       293
#     levyplus       0.53      0.30      0.39       699
#      medlevy       0.47      0.80      0.59       498
#
#     accuracy                           0.50      1557
#    macro avg       0.47      0.44      0.43      1557
# weighted avg       0.51      0.50      0.48      1557
